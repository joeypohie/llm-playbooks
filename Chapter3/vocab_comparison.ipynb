# %%
with open("cl100k_base_vocab_list.txt", "r", encoding="utf-8") as f1, open("o200k_base_vocab_list.txt", "r", encoding="utf-8") as f2:
    lines1 = set(f1.readlines())
    lines2 = set(f2.readlines())

# Lines in file1 but not in file2
diff1 = lines1 - lines2
# Lines in file2 but not in file1
diff2 = lines2 - lines1

print("Lines in file1 but not in file2:")
print("".join(diff1))
# Out:
# Lines in file1 but not in file2:
# ' "(\\<'
# '>c'
# '.setStyle'
# '_does'
# 'SharedPointer'
# 'ByName'
# '_readable'
# '.’”\n\n'
# ' ATK'
# 'foregroundColor'
# '\tpid'
# ' appropriated'
# ' maxlen'
# ' pelic'
# ' AssemblyProduct'
# '<Animator'
# 'GLenum'
# 'ToProps'
# 'uard'
# 'pageTitle'
# ' StatusCode'
# ' licked'
# ',SIGNAL'
# ' scape'
# ' spyOn'
# '_already'
# '{}]'
# 'urrect'
# ' oversh'
# ' mouseClicked'
# ' anarchist'
# ' ]);'
# 'ASHBOARD'
# '_signals'
# ' (("'
# 'erator'
# ' Dota'
# ' jsonObject'
# ' skirm'
# '_TextChanged'
# ' Stealth'
# 'ypi'
# 'erot'
# '(jLabel'
# '.setData'
# ' ObservableCollection'
# 'ScrollIndicator'
# ' forCellReuseIdentifier'
# ' astonished'
# ' indust'
# 'LayoutInflater'
# '_CHARSET'
# 'KeyName'
# 'accom'
# ' superv'
# ' Eisenhower'
# ' impoverished'
# 'RelativeTo'
# ' sharedPreferences'
# 'handleRequest'
# 'WidgetItem'
# '}");\r\n'
# ')initWith'
# '_CLI'
# ' currentPlayer'
# ' resultMap'
# 'mailbox'
# 'oward'
# 'pany'
# '_mob'
# '_emlrt'
# ...

# %%
print("\nLines in file2 but not in file1:")
print("".join(diff2))
# Out:
# Lines in file2 but not in file1:
# '桶'
# ' proses'
# '施設'
# 'etään'
# ' oktober'
# ' Konkurrenz'
# ' թ'
# 'uzzo'
# '膽'
# ' إطار'
# 'VBox'
# 'nner'
# 'ných'
# ' 宝'
# 'λλα'
# ' gallu'
# 'ildə'
# ' կենդ'
# ' tiegħ'
# ' കോട'
# '唱'
# 'idez'
# ' préparer'
# ' intemp'
# '(lb'
# ' مستويات'
# 'ixi'
# 'inkt'
# 'imist'
# ' Энэтхэг'
# 'ുക'
# 'muz'
# ' уку'
# ' күні'
# ' localidad'
# ' Innovations'
# ' Ela'
# 'վ'
# 'menn'
# ' combinaison'
# ' सभा'
# ' વિડ'
# ' escribe'
# ' аҵ'
# ' parcours'
# '액'
# ' отказаться'
# 'Sta'
# ' Olu'
# ' قامت'
# '’ident'
# '(Rel'
# ' warr'
# ' répar'
# ' здан'
# ' মত'
# ' gelernt'
# '割'
# 'ects'
# ' ಸ್ಥಾನ'
# 'æl'
# ' ನಗರ'
# 'אַנט'
# ' söyledi'
# ' pierde'
# ' escucha'
# ' سایر'
# ' elevar'
# 'isciplinary'
# 'Cult'
# 'こう'
# 'enteuer'
# ' vielä'
# 'उन्होंने'
# ' jüng'
# ' gehol'
# 'สัตย์'
# ' 하지만'
# ' vorbe'
# 'ាក'
# ' жок'
# 'що'
# ' probar'
# ' ખેલ'
# '녁'
# 'ತ್ಪ'
# " Isn't"
# 'რობა'
# 'axx'
# ' Wille'
# ' преступ'
# ' lagt'
# 'աժողով'
# ' 天天中彩票是'
# ' golfing'
# ...

# %% [markdown]
# o200k has more multilingual text than cl100k.
#
# cl100k seems to have more coding-related vocab (e.g: function names such as getEmail, or oauth)
